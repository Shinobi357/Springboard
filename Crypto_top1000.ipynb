# %%
import pandas as pd

#Kaggle dataset Url= https://www.kaggle.com/datasets/mihikaajayjadhav/top-1000-cryptocurrencies-real-time-data-2025

#Dataset describes the Top 1000 crytocurrencies and feature that determine the performace for each coin

#Seeking to determine which cryto is best to invest in for the short term and long term.

df = pd.read_csv("Downloads/CryptoDataset/crypto_top1000_dataset.csv")
df.head()
# Out:
#             id symbol      name  market_cap_rank  current_price  \
# 0      bitcoin    BTC   Bitcoin                1       92551.00
# 1     ethereum    ETH  Ethereum                2        3114.18
# 2       tether   USDT    Tether                3           1.00
# 3       ripple    XRP       XRP                4           2.17
# 4  binancecoin    BNB       BNB                5         902.22
#
#       market_cap  fully_diluted_valuation  total_volume  high_24h   low_24h  \
# 0  1849586398531             1.849586e+12  8.165691e+10  93929.00  90837.00
# 1   377137085161             3.771371e+11  2.534897e+10   3139.77   2976.94
# 2   184744825283             1.902134e+11  1.017624e+11      1.00      1.00
# 3   131451182003             2.178500e+11  4.038903e+09      2.21      2.14
# 4   124271801383             1.242718e+11  2.001782e+09    908.27    873.60
#
#    ...  price_change_percentage_24h  price_change_percentage_1h  \
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                        id symbol                 name  market_cap_rank  \
# 0                 bitcoin    BTC              Bitcoin                1
# 1                ethereum    ETH             Ethereum                2
# 2                  tether   USDT               Tether                3
# 3                  ripple    XRP                  XRP                4
# 4             binancecoin    BNB                  BNB                5
# ..                    ...    ...                  ...              ...
# 995     clash-of-lilliput    COL    Clash of Lilliput              999
# 996              alchemix   ALCX             Alchemix             1000
# 997  monerium-eur-money-2   EURE  Monerium EUR emoney             1001
# 998          metamask-usd   MUSD         MetaMask USD             1002
# 999               templar    SN3              τemplar              997
#
#      current_price     market_cap  fully_diluted_valuation  total_volume  \
# ...

# %%
df.shape
# Out:
# (1000, 30)
